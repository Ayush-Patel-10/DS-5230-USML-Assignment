# %%
import gensim
from nltk import word_tokenize
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from collections import defaultdict


# Function to get the cosine similarity between a relation and query
# Note: Be sure to prepend the relation with ns:
word2vec_model = gensim.models.Word2Vec.load('word2vec_train_dev.dat')
def get_rel_score_word2vecbase(model, rel, query):
    if rel not in word2vec_model.wv:
        return 0.0
    words = word_tokenize(query.lower())
    w_embs = []
    for w in words:
        if w in word2vec_model.wv:
            w_embs.append(word2vec_model.wv[w])
    return np.mean(cosine_similarity(w_embs, [word2vec_model.wv[rel]]))


# Function to load the graph from file
def load_graph(file):
    # Preparing the graph
    graph = defaultdict(list)
    for line in open(file):
        line = eval(line[:-1])
        graph[line[0]].append([line[1], line[2]])
    return graph


# Function to load the queries from file
# Preparing the queries
def load_queries(file):
    queries = []
    for line in open(file):
        line = eval(line[:-1])
        queries.append(line)
    return queries

# %%
import gensim
from collections import Counter
# from utils import load_graph, load_queries, get_rel_score_word2vecbase


def find_answer_bfs(model, graph, query, root, theta):
    model = model
    answers = set()
    visited = []
    queue = [root]
    query = query
    while len(queue) != 0:
        first_out = queue.pop(0)
        visited.append(first_out)
        # print('first out : ', first_out)
        neighbours_list = graph.get(first_out[0].strip('ns:'))
        if neighbours_list is not None:
            for neighbour in neighbours_list:
                relation = 'ns:' + neighbour[0]
                # print(relation)
                relevance_score = get_rel_score_word2vecbase(model, relation, query)
                # print(relevance_score)
                if neighbour[1] not in answers and neighbour[1] not in visited and relevance_score > theta:
                    # print('neighbours : ', neighbours_list)
                    queue.append(neighbour[1])
        else:
            answers.add(first_out)
            # print('answer node: ', first_out)
    return answers


def get_topic_tag(topic_code, graph):
    for out_nodes in graph.values():
        for node in out_nodes:
            if node[1] == topic_code:
                return node
    print('Can\'t retrieve node from graph')
    return ''


# Python program to illustrate the intersection
# of two lists in most simple way
def intersection(lst1, lst2):
    lst3 = [value for value in lst1 if value in lst2]
    return lst3


if __name__ == '__main__':
    graph = load_graph('graph.txt');
    queries = load_queries('annotations.txt')
    # for k, v in graph.items():
    #     print('source : ', k,  ' | destinations : ', v)
    word2vec_model = gensim.models.Word2Vec.load('word2vec_train_dev.dat')

    overlap_len = 0
    my_estimate_pool_len = 0
    ground_truth_pool_len = 0
    for query in queries:
        my_estimate_pool = []
        ground_truth_pool = []

        root = query[3][0]
        question = query[1]
        print('\n' + question)
        print('root : ', root)
        my_answers = find_answer_bfs(word2vec_model, graph, question, root, 0.3)
        print('My answers : ', my_answers)
        my_estimate_pool.extend(my_answers)
        real_answer = [q.get('AnswerArgument') for q in query[5]]
        print('Real answers : ', real_answer, '\n')
        ground_truth_pool.extend(real_answer)

        overlap_len += len(intersection(my_estimate_pool, ground_truth_pool))
        my_estimate_pool_len += len(my_estimate_pool)
        ground_truth_pool_len += len(ground_truth_pool)

    precision = overlap_len / my_estimate_pool_len
    print('Precision : ', precision)
    recall = overlap_len / ground_truth_pool_len
    print('Recall : ', recall)
    f1_score = 2 * ((precision * recall) / (precision + recall))
    print('F1_score : ', f1_score)
# Out:
# what time zones are there in the us
# root :  ['ns:m.09c7w0', 'ns:location.location.time_zones', '?x']
# My answers :  {'m.02lcrv', 'm.027wjl3', 'm.027wj2_', 'm.02hcv8', 'm.02fqwt', 'm.042g7t', 'm.02hczc', 'm.02lcqs', 'm.02lctm'}
# Real answers :  ['m.027wj2_', 'm.027wjl3', 'm.02fqwt', 'm.02hcv8', 'm.02hczc', 'm.02lcqs', 'm.02lcrv', 'm.02lctm', 'm.042g7t']
#
#
# what are major exports of the usa
# root :  ['ns:m.09c7w0', 'ns:location.statistical_region.major_exports', '?y']
# My answers :  {'m.04g4s8w', 'm.04g4s8q', 'm.04g4s90', 'm.04g4s8k'}
# Real answers :  ['m.015smg', 'm.03q9wp2', 'm.03qtd_n', 'm.03qtf10']
#
#
# what time is right now in texas
# root :  ['ns:m.07b_l', 'ns:location.location.time_zones', '?x']
# My answers :  {'m.09c7w0', 'm.02fqwt', 'm.02hczc'}
# Real answers :  ['m.02fqwt', 'm.02hczc']
#
#
# what war was george washington associated with
# root :  ['ns:m.034rd', 'ns:military.military_commander.military_commands', '?y']
# My answers :  {'m.04yykw2', 'm.064xssc', 'm.049xrhp', 'm.04yvvkf', 'm.049yn2t', 'm.09hxlzp', 'm.04yxtkk', 'm.04fvgyq', 'm.04yz499', 'm.04yv_tf', 'm.04h_fs5', 'm.04yy5qr', 'm.04yv_x3'}
# Real answers :  ['m.014pd3', 'm.014s1b', 'm.01bh42', 'm.01g09p', 'm.01g0dx', 'm.01gphc', 'm.01hgpt', 'm.01jnys', 'm.01k0s4', 'm.020_gf', 'm.0247w9', 'm.02fmsl', 'm.02fnwp', 'm.02g1n3', 'm.02pjz77', 'm.04m2k9', 'm.05b6mx0', 'm.05f78h', 'm.062pq1', 'm.066xwk', 'm.06bjm', 'm.06kd6y', 'm.07h0q2', 'm.08knpp', 'm.09r3f', 'm.0b364c', 'm.0bxl0n', 'm.0drwsm9', 'm.0h42fq', 'm.0jnh']
#
#
# what are the most common religions in the united states
# root :  ['ns:m.09c7w0', 'ns:location.statistical_region.religions', '?y']
# My answers :  {'m.03q1lvy', 'm.03q1lvq', 'm.03q1lvh', 'm.03q1lwl', 'm.0_hhjkj', 'm.03q1lw4'}
# Real answers :  ['m.01lp8', 'm.03_gx', 'm.03j6c', 'm.07w8f', 'm.092bf5', 'm.0flw86', 'm.0kpl']
#
#
# what are the names of michael jackson children
# root :  ['ns:m.09889g', 'ns:people.person.children', '?x']
# My answers :  {'m.0652zrb', 'm.065qbyj', 'm.0nf3l7x', 'm.09kkmyf', 'm.0598rm4', 'm.0598rmb', 'm.09kkmyr', 'm.0j17fx_', 'm.0652zr5'}
# Real answers :  ['m.0598rm4', 'm.0598rmb', 'm.065qbyj']
#
#
# when michael jordan got drafted
# root :  ['ns:m.054c1', 'ns:sports.drafted_athlete.drafted', '?y']
# My answers :  {'m.02h7cgv'}
# Real answers :  ['m.06jncs']
#
#
# what type of government and economic system does the united states have
# root :  ['ns:m.09c7w0', 'ns:location.country.form_of_government', '?x']
# My answers :  {'m.0j729', 'm.0c9rw5', 'm.01d9r3'}
# Real answers :  ['m.01d9r3', 'm.0c9rw5', 'm.0j729']
#
#
# what country was george washington from
# root :  ['ns:m.034rd', 'ns:people.person.nationality', '?x']
# My answers :  {'m.04yykw2', 'm.064xssc', 'm.049xrhp', 'm.04yvvkf', 'm.049yn2t', 'm.09hxlzp', 'm.04yxtkk', 'm.04fvgyq', 'm.04yz499', 'm.04yv_tf', 'm.04h_fs5', 'm.04yy5qr', 'm.04yv_x3'}
# Real answers :  ['m.02p89zz']
#
#
# what are the major imports of the united states
# root :  ['ns:m.09c7w0', 'ns:location.statistical_region.major_imports', '?y']
# My answers :  {'m.07b_l', 'm.06yxd', 'm.03v0t'}
# Real answers :  ['m.015smg', 'm.03qtd_n', 'm.03xm3m', 'm.09j2d', 'm.0c_jw']
#
#
# on which continent is the usa located
# root :  ['ns:m.09c7w0', 'ns:base.locations.countries.continent', '?x']
# My answers :  {'m.059g4'}
# Real answers :  ['m.059g4']
#
#
# what continent is the usa located in
# root :  ['ns:m.09c7w0', 'ns:base.locations.countries.continent', '?x']
# My answers :  {'m.09nqf'}
# Real answers :  ['m.0_cdzjp', 'm.027fwmt', 'm.02qsfv', 'm.031t2d', 'm.036ytw', 'm.05f5tq', 'm.065mvrb', 'm.07hqvg', 'm.0djb05y', 'm.0v435l3', 'm.0v43grn']
#
#
# what timezone is illinois on
# root :  ['ns:m.03v0t', 'ns:location.location.time_zones', '?x']
# My answers :  {'m.09c7w0', 'm.02fqwt'}
# Real answers :  ['m.02fqwt']
#
#
# what year michael jordan came in the nba
# root :  ['ns:m.054c1', 'ns:sports.drafted_athlete.drafted', '?y']
# My answers :  {'m.02h7cgv'}
# Real answers :  ['m.06jncs']
#
#
# what is the political system of the us
# root :  ['ns:m.09c7w0', 'ns:location.country.form_of_government', '?x']
# My answers :  {'m.0j729', 'm.0c9rw5', 'm.09nqf', 'm.01d9r3'}
# Real answers :  ['m.01d9r3', 'm.0c9rw5', 'm.0j729']
#
#
# what illnesses did george washington have
# root :  ['ns:m.034rd', 'ns:medicine.notable_person_with_medical_condition.condition', '?x']
# My answers :  {'m.04yykw2', 'm.064xssc', 'm.049xrhp', 'm.04yvvkf', 'm.049yn2t', 'm.09hxlzp', 'm.04yxtkk', 'm.04fvgyq', 'm.04yz499', 'm.04yv_tf', 'm.04h_fs5', 'm.04yy5qr', 'm.04yv_x3'}
# Real answers :  ['m.0542n', 'm.06vr2', 'm.07jwr']
#
#
# what illnesses did george washington suffer from
# root :  ['ns:m.034rd', 'ns:medicine.notable_person_with_medical_condition.condition', '?x']
# My answers :  {'m.04yykw2', 'm.064xssc', 'm.049xrhp', 'm.04yvvkf', 'm.07jwr', 'm.0542n', 'm.049yn2t', 'm.06vr2', 'm.09hxlzp', 'm.04fvgyq', 'm.04yxtkk', 'm.04yz499', 'm.04yv_tf', 'm.04h_fs5', 'm.04yy5qr', 'm.04yv_x3'}
# Real answers :  ['m.0542n', 'm.06vr2', 'm.07jwr']
#
#
# where is south carolina located
# root :  ['ns:m.06yxd', 'ns:base.aareas.schema.administrative_area.administrative_parent', '?x']
# My answers :  {'m.09c7w0', 'm.0fv_t'}
# Real answers :  ['m.09c7w0']
#
#
# what kind of government does the united states have today
# root :  ['ns:m.09c7w0', 'ns:location.country.form_of_government', '?x']
# My answers :  {'m.0j729', 'm.0c9rw5', 'm.01d9r3'}
# Real answers :  ['m.01d9r3', 'm.0c9rw5', 'm.0j729']
#
#
# who were michael jackson 's brothers and sisters
# root :  ['ns:m.09889g', 'ns:people.person.sibling_s', '?y']
# My answers :  {'m.012mtk5b', 'm.06w81qp', 'm.0y4qyrn', 'm.01hl4l8', 'g.1236srvy', 'm.0vypv96', 'm.036ytw', 'm.09kkmyf', 'm.0598rm4', 'm.01lc5', 'm.07hqvg', 'm.01hl3t4', 'm.06j6l', 'm.047qwf7', 'm.0652zr5', 'm.07_lq', 'm.065qbyj', 'm.0407f', 'm.096y7s', 'm.026z9', 'm.064t9', 'm.01n7xgt', 'm.05bt6j', 'm.0132tgw6', 'm.0jwt60n', 'm.01b9db', 'g.11bbxlkxxc', 'm.02lkt', 'm.01hl45_', 'm.0nf3l7x', 'm.03jgszc', 'm.01hl4hb', 'm.02vjzr', 'm.0598rmb', 'm.01hl2j6', 'm.01k9bm5', 'm.06308p', 'm.021_z5', 'm.01hl48b', 'm.04ct6p', 'm.01hl40t', 'm.01hl444', 'm.06by7', 'm.0652zrb', 'm.02st1p', 'm.02srz6', 'm.06_y1fq', 'm.02st0w', 'm.0q8flcq', 'm.081nh', 'm.09kkmyr', 'm.01hl3jm', 'm.0g6_q__', 'm.03jg4tt', 'm.0w508xx', 'm.0ggx5q', 'm.0j17fx_', 'm.010klcpt'}
# Real answers :  ['m.013v5j', 'm.01s993', 'm.01s9b9', 'm.01zmpg', 'm.023_5s', 'm.0247h4', 'm.04_70v', 'm.0598rr3', 'm.0gbwp', 'm.0nf3l7y']
#
#
# what is zip code for chicago illinois
# root :  ['ns:m.01_d4', 'ns:location.citytown.postal_codes', '?x']
# My answers :  {'m.01_6r1z', 'm.07nqmg3', 'm.01_6rf1', 'm.01_6pnb', 'm.07nqmgs', 'm.01_6pdj', 'm.01_6q1q', 'm.0n8yyvt', 'm.01_7140', 'm.01_75zb', 'm.01_6q0k', 'm.01_6sws', 'm.0bl8mx', 'm.07nqmk5', 'm.01_6pp5', 'm.01_73_n', 'm.07nqms5', 'm.03dpqrm', 'm.01_6qz6', 'm.07nqmlh', 'm.06_7k', 'm.01_6p6k', '
#
#
# what year did michael jordan started his career
# root :  ['ns:m.054c1', 'ns:sports.drafted_athlete.drafted', '?y']
# My answers :  {'m.02h7cgv'}
# Real answers :  ['m.06jncs']
#
#
# what year was michael jordan rookie year
# root :  ['ns:m.054c1', 'ns:sports.drafted_athlete.drafted', '?y']
# My answers :  {'m.02h7cgv'}
# Real answers :  ['m.06jncs']
#
#
# what timezone is the state of texas
# root :  ['ns:m.07b_l', 'ns:location.location.time_zones', '?x']
# My answers :  {'m.09c7w0', 'm.02fqwt', 'm.02hczc', 'm.0vzm'}
# Real answers :  ['m.02fqwt', 'm.02hczc']
#
#
# what was basketball player michael jordan 's major in college
# root :  ['ns:m.054c1', 'ns:people.person.education', '?y']
# My answers :  set()
# Real answers :  ['m.07xc_j']
#
#
# what all did michael jackson own
# root :  ['ns:m.09889g', 'ns:architecture.architectural_structure_owner.structures_owned', '?y']
# My answers :  {'m.0j17fx_'}
# Real answers :  ['m.02vlwj']
#
#
# what system of government is used in the united states of america
# root :  ['ns:m.09c7w0', 'ns:location.country.form_of_government', '?x']
# My answers :  {'m.0j729', 'm.0c9rw5', 'm.09nqf', 'm.01d9r3'}
# Real answers :  ['m.01d9r3', 'm.0c9rw5', 'm.0j729']
#
#
# what products are made in the usa
# root :  ['ns:m.09c7w0', 'ns:location.statistical_region.major_exports', '?y']
# My answers :  set()
# Real answers :  ['m.015smg', 'm.03q9wp2', 'm.03qtd_n', 'm.03qtf10']
#
#
# what type of government is the us government
# root :  ['ns:m.09c7w0', 'ns:location.country.form_of_government', '?x']
# My answers :  {'m.0j729', 'm.0c9rw5', 'm.09nqf', 'm.01d9r3'}
# Real answers :  ['m.01d9r3', 'm.0c9rw5', 'm.0j729']
#
#
# what is george washington 's hometown
# root :  ['ns:m.034rd', 'ns:people.person.place_of_birth', '?x']
# My answers :  {'m.04yykw2', 'm.064xssc', 'm.049xrhp', 'm.04yvvkf', 'm.049yn2t', 'm.09hxlzp', 'm.04yxtkk', 'm.04fvgyq', 'm.04yz499', 'm.04yv_tf', 'm.04h_fs5', 'm.04yy5qr', 'm.04yv_x3'}
# Real answers :  ['m.0mmyl']
#
#
# where to hang out in chicago
# root :  ['ns:m.01_d4', 'ns:travel.travel_destination.tourist_attractions', '?x']
# My answers :  {'m.04h9qj', 'm.025v4fb', 'm.0g_8d0', 'm.01dlzc', 'm.0d9wz', 'm.02rvwrv', 'm.0n8yyvt', 'm.02jw0z', 'm.02vv_6w', 'm.0bl8mx', 'm.0b0sh', 'm.03y4l3', 'm.05zv09', 'm.0j2m3px', 'm.0c7ln', 'm.027hqc_', 'm.06_7k', 'm.0b28z', 'm.094154', 'm.07qbm4', 'm.0n4_xtw', 'm.021czc', 'm.0w7m2x9'}
# Real answers :  ['m.01dlzc', 'm.021czc', 'm.025v4fb', 'm.027hqc_', 'm.02jw0z', 'm.02rvwrv', 'm.02vv_6w', 'm.03y4l3', 'm.04h9qj', 'm.05zv09', 'm.06_7k', 'm.07qbm4', 'm.094154', 'm.0b0sh', 'm.0b28z', 'm.0bl8mx', 'm.0c7ln', 'm.0d9wz', 'm.0g_8d0', 'm.0j2m3px', 'm.0n4_xtw', 'm.0n8yyvt', 'm.0w7m2x9']
#
#
# what school did michael jordan go to
# root :  ['ns:m.054c1', 'ns:people.person.education', '?y']
# My answers :  {'m.04g36q3', 'm.02h7cgv', 'm.0jwk2zd'}
# Real answers :  ['m.07qymj', 'm.0bx8pn']
#
#
# what disease michael jackson
# root :  ['ns:m.09889g', 'ns:medicine.notable_person_with_medical_condition.condition', '?x']
# My answers :  {'m.012mtk5b', 'm.06w81qp', 'm.0y4qyrn', 'm.01hl4l8', 'g.1236srvy', 'm.0vypv96', 'm.036ytw', 'm.09kkmyf', 'm.01lc5', 'm.07hqvg', 'm.01hl3t4', 'm.06j6l', 'm.047qwf7', 'm.0652zr5', 'm.07_lq', 'm.0407f', 'm.096y7s', 'm.026z9', 'm.064t9', 'm.01n7xgt', 'm.05bt6j', 'm.0132tgw6', 'm.0jwt60n', 'm.01b9db', 'g.11bbxlkxxc', 'm.026k8yn', 'm.02lkt', 'm.01hl45_', 'm.0nf3l7x', 'm.03jgszc', 'm.01hl4hb', 'm.02vjzr', 'm.01hl2j6', 'm.01k9bm5', 'm.06308p', 'm.021_z5', 'm.01hl48b', 'm.04ct6p', 'm.01hl40t', 'm.01hl444', 'm.06by7', 'm.0652zrb', 'm.02st1p', 'm.02srz6', 'm.06_y1fq', 'm.02st0w', 'm.0q8flcq', 'm.081nh', 'm.09kkmyr', 'm.01hl3jm', 'm.0g6_q__', 'm.03jg4tt', 'm.0w508xx', 'm.0ggx5q', 'm.0j17fx_', 'm.010klcpt'}
# Real answers :  ['m.026k8yn']
#
#
# what is the capital city of south carolina
# root :  ['ns:m.06yxd', 'ns:base.aareas.schema.administrative_area.capital', '?x']
# My answers :  {'m.09c7w0', 'm.0fv_t'}
# Real answers :  ['m.0fv_t']
#
#
# what does michael jackson like to eat
# root :  ['ns:m.09889g', 'ns:food.diet_follower.follows_diet', '?x']
# My answers :  {'m.07hqvg', 'm.0j17fx_', 'm.036ytw', 'm.07_lq'}
# Real answers :  ['m.07_lq']
#
#
# what times is it in texas
# root :  ['ns:m.07b_l', 'ns:location.location.time_zones', '?x']
# My answers :  {'m.09c7w0', 'm.02fqwt', 'm.02hczc'}
# Real answers :  ['m.02fqwt', 'm.02hczc']
#
#
# what kind of music did michael jackson sing
# root :  ['ns:m.09889g', 'ns:music.artist.genre', '?x']
# My answers :  {'m.012mtk5b', 'm.06w81qp', 'm.0y4qyrn', 'm.01hl4l8', 'g.1236srvy', 'm.0vypv96', 'm.036ytw', 'm.09kkmyf', 'm.07hqvg', 'm.01hl3t4', 'm.06j6l', 'm.047qwf7', 'm.0652zr5', 'm.07_lq', 'm.096y7s', 'm.026z9', 'm.064t9', 'm.01n7xgt', 'm.05bt6j', 'm.0132tgw6', 'm.0jwt60n', 'g.11bbxlkxxc', 'm.02lkt', 'm.01hl45_', 'm.0nf3l7x', 'm.03jgszc', 'm.01hl4hb', 'm.02vjzr', 'm.01hl2j6', 'm.01k9bm5', 'm.06308p', 'm.021_z5', 'm.01hl48b', 'm.01hl40t', 'm.01hl444', 'm.06by7', 'm.0652zrb', 'm.02st1p', 'm.02srz6', 'm.06_y1fq', 'm.02st0w', 'm.0q8flcq', 'm.09kkmyr', 'm.01hl3jm', 'm.0g6_q__', 'm.03jg4tt', 'm.0w508xx', 'm.0ggx5q', 'm.010klcpt'}
# Real answers :  ['m.021_z5', 'm.025sc50', 'm.026z9', 'm.02bqnt', 'm.02lkt', 'm.02lnbg', 'm.02vjzr', 'm.02x8m', 'm.03c34yl', 'm.05bt6j', 'm.064t9', 'm.06by7', 'm.06j6l', 'm.0ggx5q', 'm.0gywn']
#
#
# what are major religions in the united states
# root :  ['ns:m.09c7w0', 'ns:location.statistical_region.religions', '?y']
# My answers :  {'m.03q1lvy', 'm.03q1lvq', 'm.03q1lvh', 'm.03q1lwl', 'm.0_hhjkj', 'm.03q1lw4'}
# Real answers :  ['m.01lp8', 'm.03_gx', 'm.03j6c', 'm.07w8f', 'm.092bf5', 'm.0flw86', 'm.0kpl']
#
#
# what war did george washington help win
# root :  ['ns:m.034rd', 'ns:military.military_commander.military_commands', '?y']
# My answers :  {'m.04yykw2', 'm.064xssc', 'm.049xrhp', 'm.04yvvkf', 'm.02fmsl', 'm.09r3f', 'm.049yn2t', 'm.09hxlzp', 'm.04yxtkk', 'm.0jnh', 'm.04fvgyq', 'm.04yz499', 'm.04yv_tf', 'm.04h_fs5', 'm.04yy5qr', 'm.04yv_x3'}
# Real answers :  ['m.014pd3', 'm.014s1b', 'm.01bh42', 'm.01g09p', 'm.01g0dx', 'm.01gphc', 'm.01hgpt', 'm.01jnys', 'm.01k0s4', 'm.020_gf', 'm.0247w9', 'm.02fmsl', 'm.02fnwp', 'm.02g1n3', 'm.02pjz77', 'm.04m2k9', 'm.05b6mx0', 'm.05f78h', 'm.062pq1', 'm.066xwk', 'm.06bjm', 'm.06kd6y', 'm.07h0q2', 'm.08knpp', 'm.09r3f', 'm.0b364c', 'm.0bxl0n', 'm.0drwsm9', 'm.0h42fq', 'm.0jnh']
#
#
# what war was george washington president during
# root :  ['ns:m.034rd', 'ns:military.military_commander.military_commands', '?y']
# My answers :  {'m.04yykw2', 'm.064xssc', 'm.049xrhp', 'm.04yvvkf', 'm.02fmsl', 'm.09r3f', 'm.049yn2t', 'm.09hxlzp', 'm.04yxtkk', 'm.0jnh', 'm.04fvgyq', 'm.04yz499', 'm.04yv_tf', 'm.04h_fs5', 'm.04yy5qr', 'm.04yv_x3'}
# Real answers :  ['m.014pd3', 'm.014s1b', 'm.01bh42', 'm.01g09p', 'm.01g0dx', 'm.01gphc', 'm.01hgpt', 'm.01jnys', 'm.01k0s4', 'm.020_gf', 'm.0247w9', 'm.02fmsl', 'm.02fnwp', 'm.02g1n3', 'm.02pjz77', 'm.04m2k9', 'm.05b6mx0', 'm.05f78h', 'm.062pq1', 'm.066xwk', 'm.06bjm', 'm.06kd6y', 'm.07h0q2', 'm.08knpp', 'm.09r3f', 'm.0b364c', 'm.0bxl0n', 'm.0drwsm9', 'm.0h42fq', 'm.0jnh']
#
#
# what school did michael jackson attend
# root :  ['ns:m.09889g', 'ns:people.person.education', '?y']
# My answers :  {'m.0n1cs5l'}
# Real answers :  ['m.06lhpy']
#
#
# what was the cause of death of michael jackson
# root :  ['ns:m.09889g', 'ns:people.deceased_person.cause_of_death', '?x']
# My answers :  {'m.012mtk5b', 'm.06w81qp', 'm.0y4qyrn', 'm.01hl4l8', 'g.1236srvy', 'm.0vypv96', 'm.01hl3t4', 'm.047qwf7', 'm.0gg4h', 'm.096y7s', 'm.01n7xgt', 'm.0132tgw6', 'm.0jwt60n', 'g.11bbxlkxxc', 'm.01hl45_', 'm.03jgszc', 'm.01hl4hb', 'm.01hl2j6', 'm.01k9bm5', 'm.06308p', 'm.01hl48b', 'm.01hl40t', 'm.01hl444', 'm.02st1p', 'm.02srz6', 'm.06_y1fq', 'm.02st0w', 'm.0q8flcq', 'm.01hl3jm', 'm.03jg4tt', 'm.0g6_q__', 'm.0w508xx', 'm.010klcpt'}
# Real answers :  ['m.0gg4h']
#
#
# what is the capital city of texas usa
# root :  ['ns:m.07b_l', 'ns:location.us_state.capital', '?x']
# My answers :  {'m.09c7w0', 'm.0vzm'}
# Real answers :  ['m.0vzm']
#
#
# who influenced michael jackson
# root :  ['ns:m.09889g', 'ns:influence.influence_node.influenced_by', '?x']
# My answers :  {'m.012mtk5b', 'm.06w81qp', 'm.0y4qyrn', 'm.01hl4l8', 'g.1236srvy', 'm.0vypv96', 'm.036ytw', 'm.09kkmyf', 'm.0598rm4', 'm.01lc5', 'm.07hqvg', 'm.01hl3t4', 'm.06j6l', 'm.047qwf7', 'm.0652zr5', 'm.07_lq', 'm.065qbyj', 'm.0407f', 'm.096y7s', 'm.026z9', 'm.064t9', 'm.01n7xgt', 'm.05bt6j', 'm.0132tgw6', 'm.0jwt60n', 'm.01b9db', 'g.11bbxlkxxc', 'm.026k8yn', 'm.02lkt', 'm.01hl45_', 'm.0nf3l7x', 'm.03jgszc', 'm.01hl4hb', 'm.02vjzr', 'm.0598rmb', 'm.01hl2j6', 'm.01k9bm5', 'm.06308p', 'm.021_z5', 'm.01hl48b', 'm.04ct6p', 'm.01hl40t', 'm.01hl444', 'm.06by7', 'm.0652zrb', 'm.02st1p', 'm.02srz6', 'm.06_y1fq', 'm.02st0w', 'm.0q8flcq', 'm.081nh', 'm.09kkmyr', 'm.01hl3jm', 'm.0g6_q__', 'm.03jg4tt', 'm.0w508xx', 'm.0ggx5q', 'm.010klcpt'}
# Real answers :  ['m.01_6p_k', 'm.01_6p6k', 'm.01_6p8l', 'm.01_6p9s', 'm.01_6pdj', 'm.01_6pgd', 'm.01_6ph7', 'm.01_6pmb', 'm.01_6pnb', 'm.01_6pp5', 'm.01_6ps8', 'm.01_6pvy', 'm.01_6pxw', 'm.01_6q0k', 'm.01_6q1q', 'm.01_6q8p', 'm.01_6q9q', 'm.01_6qcm', 'm.01_6qjr', 'm.01_6qp4', 'm.01_6qrp', 'm.01_6qsj', 'm.01_6qz6', 'm.01_6r1z', 'm.01_6r78', 'm.01_6r82', 'm.01_6rf1', 'm.01_6rfw', 'm.01_6s_6', 'm.01_6s0l', 'm.01_6smy', 'm.01_6sws', 'm.01_6t1b', 'm.01_6t43', 'm.01_6t4y', 'm.01_6t5r', 'm.01_6t95', 'm.01_6tgy', 'm.01_6v4j', 'm.01_6v6w', 'm.01_6y3n', 'm.01_6zk1', 'm.01_7140', 'm.01_71cx', 'm.01_72xz', 'm.01_73_n', 'm.01_75zb', 'm.01_77qt', 'm.01_77x6', 'm.01_78lh', 'm.01_78nm', 'm.01_78wb', 'm.01_795b', 'm.01_7gfz', 'm.03dpqpb', 'm.03dpqrm', 'm.065rklh', 'm.07nqmf7', 'm.07nqmfg', 'm.07nqmfp', 'm.07nqmfx', 'm.07nqmg_', 'm.07nqmg3', 'm.07nqmgb', 'm.07nqmgk', 'm.07nqmgs', 'm.07nqmh6', 'm.07nqmhf', 'm.07nqmhn', 'm.07nqmhw', 'm.07nqmj2', 'm.07nqmj9', 'm.07nqmjj', 'm.07nqmjr', 'm.07nqmjz', 'm.07nqmk5', 'm.07nqmkd', 'm.07nqmkm', 'm.07nqmkv', 'm.07nqml1', 'm.07nqml8', 'm.07nqmlh', 'm.07nqmlq', 'm.07nqmly', 'm.07nqms5', 'm.09sh942', 'm.0gs227r']
#
#
# what state in chicago in
# root :  ['ns:m.01_d4', 'ns:base.biblioness.bibs_location.state', '?x']
# My answers :  set()
# Real answers :  ['m.03v0t']
#
#
# where was george washington originally from
# root :  ['ns:m.034rd', 'ns:people.person.place_of_birth', '?x']
# My answers :  {'m.04yykw2', 'm.064xssc', 'm.049xrhp', 'm.04yvvkf', 'm.02fmsl', 'm.09r3f', 'm.049yn2t', 'm.09hxlzp', 'm.04yxtkk', 'm.0jnh', 'm.04fvgyq', 'm.04yz499', 'm.04yv_tf', 'm.04h_fs5', 'm.04yy5qr', 'm.04yv_x3'}
# Real answers :  ['m.0mmyl']
#
#
# where did michael jackson went to school
# root :  ['ns:m.09889g', 'ns:people.person.education', '?y']
# My answers :  {'m.0n1cs5l'}
# Real answers :  ['m.06lhpy']
#
#
# what year did michael jordan get drafted
# root :  ['ns:m.054c1', 'ns:sports.drafted_athlete.drafted', '?y']
# My answers :  {'m.02h7cgv'}
# Real answers :  ['m.06jncs']
#
#
# what form of government do we have in the usa
# root :  ['ns:m.09c7w0', 'ns:location.country.form_of_government', '?x']
# My answers :  {'m.0j729', 'm.0c9rw5', 'm.01d9r3'}
# Real answers :  ['m.01d9r3', 'm.0c9rw5', 'm.0j729']
#
#
# what kind government does the us have
# root :  ['ns:m.09c7w0', 'ns:location.country.form_of_government', '?x']
# My answers :  {'m.0j729', 'm.0c9rw5', 'm.01d9r3'}
# Real answers :  ['m.01d9r3', 'm.0c9rw5', 'm.0j729']
#
# Precision :  0.34977578475336324
# Recall :  0.4642857142857143
# F1_score :  0.39897698209718674
